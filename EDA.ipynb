# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hrtest=pd.read_csv('test_2umaH9m.csv')

# %%
hrtrain=pd.read_csv('train_LZdllcl.csv')

# %%
hrtrain.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
hrtrain.shape
# Out:
# (54808, 14)

# %%
hrtrain.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# KPIs_met >80%             int64
# awards_won?               int64
# avg_training_score        int64
# is_promoted               int64
# dtype: object

# %%
hrtrain.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
#cross tabulation of education and gender
#cross tabulation of is_promoted and awardswon
#average age of gender
#how many types of recruitment channel is there
#cross tabulation of gender and KPIs_met>80%
#cross tabulation of recruitment channel and is_promoted
#cross tabulation of recruitment channel and awardswon
#cross tabulation of department  and is_promoted
#cross tabulation of department  and awardswon

# %%
#cross tabulation of education and gender
pd.crosstab(hrtrain.education,hrtrain.gender)
# Out:
# gender                f      m
# education
# Bachelor's        10854  25815
# Below Secondary     289    516
# Master's & above   4778  10147

# %%
pd.crosstab(hrtrain.education,hrtrain.gender).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='education'>

# %%
#cross tabulation of recruitment channel and is_promoted
pd.crosstab(hrtrain.recruitment_channel,hrtrain.is_promoted)
# Out:
# is_promoted              0     1
# recruitment_channel
# other                27890  2556
# referred              1004   138
# sourcing             21246  1974

# %%
pd.crosstab(hrtrain.recruitment_channel,hrtrain.is_promoted).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='recruitment_channel'>

# %%
#how many types of recruitment channel is there with bar
hrtrain.recruitment_channel.value_counts()
# Out:
# other       30446
# sourcing    23220
# referred     1142
# Name: recruitment_channel, dtype: int64

# %%
hrtrain.recruitment_channel.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#cross tabulation of is_promoted and awardswon
pd.crosstab(hrtrain['awards_won?'],hrtrain.is_promoted)
# Out:
# is_promoted      0     1
# awards_won?
# 0            49429  4109
# 1              711   559

# %%
pd.crosstab(hrtrain['awards_won?'],hrtrain.is_promoted).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='awards_won?'>

# %%
#cross tabulation of gender and KPIs_met>80%
pd.crosstab(hrtrain.gender,hrtrain['KPIs_met >80%'])
# Out:
# KPIs_met >80%      0      1
# gender
# f              10123   6189
# m              25394  13102

# %%
pd.crosstab(hrtrain.gender,hrtrain['KPIs_met >80%']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
#cross tabulation of department  and is_promoted
pd.crosstab(hrtrain.department,hrtrain.is_promoted)
# Out:
# is_promoted            0     1
# department
# Analytics           4840   512
# Finance             2330   206
# HR                  2282   136
# Legal                986    53
# Operations         10325  1023
# Procurement         6450   688
# R&D                  930    69
# Sales & Marketing  15627  1213
# Technology          6370   768

# %%
pd.crosstab(hrtrain.department,hrtrain.is_promoted).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='department'>

# %%
#cross tabulation of department  and awardswon
pd.crosstab(hrtrain.department,hrtrain['awards_won?'])
# Out:
# awards_won?            0    1
# department
# Analytics           5222  130
# Finance             2466   70
# HR                  2373   45
# Legal               1014   25
# Operations         11086  262
# Procurement         6967  171
# R&D                  978   21
# Sales & Marketing  16479  361
# Technology          6953  185

# %%
pd.crosstab(hrtrain.department,hrtrain['awards_won?']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='department'>

# %%
#cross tabulation of recruitment channel and awardswon
pd.crosstab(hrtrain.recruitment_channel,hrtrain['awards_won?'])
# Out:
# awards_won?              0    1
# recruitment_channel
# other                29720  726
# referred              1112   30
# sourcing             22706  514

# %%
pd.crosstab(hrtrain.recruitment_channel,hrtrain['awards_won?']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='recruitment_channel'>

# %%
#plotting pie chart for region
hrtrain.region.value_counts().plot(kind='pie',radius=3)
# Out:
# <AxesSubplot:ylabel='region'>

# %%
#plotting piechart for gender
hrtrain.gender.value_counts().plot(kind='pie',radius=1)
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
#plotting piechart for department
hrtrain.department.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='department'>
